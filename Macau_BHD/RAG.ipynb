# %%
import pandas as pd


df = pd.read_csv('testbase.csv')

query_texts = {}

for i in range(1, 21):
    hole_id = f'BH{i}'
    mask = df['Hole_ID'] == hole_id

    hole_df = df.loc[mask].copy()
    
    hole_df['formatted'] = hole_df['Depth'].astype(str) + 'm, ' + hole_df['description']
    formatted_text = '\n'.join(hole_df['formatted'].tolist())
    
    query_texts[f'query_text{i}'] = formatted_text

for i in range(1, 21):
    key = f'query_text{i}'
    print(f'===== {key} =====')
    print(query_texts[key])
    print()
# Out:
# ===== query_text1 =====
# 0.0m, loose, gray to yellowish fine sand
# 7.4m, very soft, dark gray clay, occasional humus
# 18.7m, loose, gray coarse sand
# 19.5m, firm, gray to yellowish clay locally laminated, sand
# 25.0m, soft, dark gray clay, occasional humus
# 25.7m, firm, gray to yellowish clay locally laminated, sand
# 28.9m, soft to firm, gray clay
# 32.4m, medium dense, gray to yellowish coarse sand
# 34.0m, firm, gray clay
# 36.5m, weak, grayish yellow, pinkish red, grayish white, completely decomposed granite
# 37.6m, strong, grayish yellow, pinkish red, grayish white, moderately decomposed granite
# 38.2m, weak, grayish yellow, pinkish red, grayish white, completely decomposed granite
# 42.0m, weak, grayish yellow, pinkish red, grayish white, highly decomposed granite
# 48.32m, strong to very strong, grayish yellow pinkish red, grayish white, moderately decomposed granite
#
# ===== query_text2 =====
# 0.0m, loose, gray to yellowish fine sand
# 9.5m, loose, gray coarse sand, very soft clay
# 13.5m, very soft, dark gray clay, occasionally, humus, fine sand, shells
# 16.8m, firm to stiff, gray to yellowish clay locally laminated, sand
# 20.5m, very soft, dark gray clay, occasionally, organic materials
# 23.2m, strong, grayish yellow, pinkish red, grayish white, moderately decomposed granite
# 24.57m, stiff to very stiff, grayish yellow residual soil
# 28.72m, strong to very strong, grayish yellow, pinkish red, grayish white, moderately decomposed granite
#
# ===== query_text3 =====
# 0.0m, loose, gray to yellowish fine sand, cobbles
# 9.5m, loose, grayish yellow coarse sand, shell fragments
# 15.4m, soft, dark gray clay, occasionally, humus, sand
# 18.0m, stiff, grayish yellow clay, locally laminated, sand
# 21.0m, very soft, dark gray clay, occasionally, humus
# 25.0m, stiff to very stiff, grayish yellow sandy clay
# 28.5m, weak, grayish yellow, pinkish red, grayish white, completely decomposed granite
# 36.37m, strong, grayish yellow, pinkish red, grayish white, highly decomposed granite
# 44.7m, strong to very strong, grayish yellow, pinkish red, grayish white, moderately decomposed granite
#
# ===== query_text4 =====
# 0.0m, cobbles, concrete, construction waste
# 9.5m, loose, gray to yellowish gray fine sand
# 11.5m, soft to firm, dark gray clay, organic materials, shell fragments
# 15.0m, loose, gray to yellowish gray medium sand
# 17.0m, soft, dark gray clay, occasionally, organic materials, fine sand
# 17.7m, stiff to very stiff, grayish yellow residual soil
# 20.66m, moderately strong to strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite
#
# ===== query_text5 =====
# 0.0m, boulders involved, sand, granite
# 7.8m, loose, gray fine sand, shell fragments, occasionally, very soft clay
# 10.2m, very soft, dark gray clay, occasionally, organic materials, shell fragments
# 13.5m, loose to medium dense, gray to yellowish gray coarse sand
# 17.6m, firm, gray to yellowish gray clay occasionally, sand
# 20.5m, medium dense, gray to yellowish gray coarse clayey sand
# 21.5m, firm, gray to yellowish gray coarse sandy clay
# 24.2m, firm, gray clay occasionally, fine sand, organic materials
# 26.5m, loose, gray to yellowish gray coarse clayey sand
# 27.6m, medium dense, gray to yellowish gray coarse sand
# 31.0m, firm, gray to yellowish gray coarse sandy clay
# 32.5m, stiff to very stiff, grayish yellow residual soil
# 36.5m, extremely weak, grayish yellow pinkish red, grayish white, completely decomposed granite
# 38.5m, extremely weak, grayish yellow pinkish red, grayish white, highly decomposed granite
# 42.7m, medium strong, grayish yellow pinkish red, grayish white, moderately decomposed granite
#
# ===== query_text6 =====
# 0.0m, loose, gray to yellowish fine sand
# 7.5m, very soft, dark gray clay, occasionally, shell fragments, organic materials
# 16.0m, loose, gray coarse sand, around 15% very soft clay
# 18.3m, soft to stiff, gray clay locally laminated, sand
# 20.6m, very soft, dark gray clay, occasionally, organic materials
# 29.0m, firm to stiff, gray clay
# 35.0m, weak, grayish yellow pinkish red, grayish white, completely decomposed granite
# 37.0m, weak, grayish yellow pinkish red, grayish white, highly decomposed granite
# 40.3m, strong, grayish yellow pinkish red, grayish white, moderately decomposed granite
# 42.14m, weak, grayish yellow pinkish red, grayish white, highly decomposed granite
# 43.54m, strong to very strong, grayish yellow pinkish red, grayish white, moderately decomposed granite
#
# ===== query_text7 =====
# 0.0m, loose, occasionally coarse dense, brown medium backfill sand
# 2.8m, very soft, dark gray clay, occasionally, organic materials, shell fragments
# 15.6m, firm, gray clay, locally laminated, sand
# 22.5m, loose, gray coarse sand
# 26.5m, soft, gray clay locally laminated, sand
# 29.8m, firm to stiff, gray clay, sand
# 32.0m, stiff to very stiff, grayish yellow residual soil
# 36.0m, weak, grayish yellow pinkish red, grayish white, completely decomposed granite
# 42.0m, weak, grayish yellow pinkish red, grayish white, highly decomposed granite
# 56.55m, strong to very strong, grayish yellow pinkish red, grayish white, moderately decomposed granite
#
# ===== query_text8 =====
# 0.0m, loose, gray to yellowish fine sand
# 7.6m, very soft, dark gray clay, occasional humus
# 8.5m, loose, gray coarse sand
# 12.9m, weak, grayish yellow pinkish red, grayish white, completely decomposed granite
# 18.0m, weak, grayish yellow pinkish red, grayish white, highly decomposed granite
# 31.98m, strong to very strong, grayish yellow pinkish red, grayish white, moderately decomposed granite
#
# ===== query_text9 =====
# 0.0m, loose, gray to yellowish fine sand
# 5.8m, very soft, dark gray clay, occasional humus
# 8.6m, loose, gray coarse sand, very soft clay
# 12.5m, very soft, dark gray clay, occasional humus
# 16.5m, loose, gray coarse sand occasionally, clay
# 20.5m, stiff to very stiff, grayish yellow residual soil
# 25.0m, weak, grayish yellow pinkish red, grayish white, completely decomposed granite
# 29.0m, weak, grayish yellow pinkish red, grayish white, highly decomposed granite
# 35.05m, strong to very strong, grayish yellow pinkish red, grayish white, moderately decomposed granite
#
# ===== query_text10 =====
# 0.0m, medium dense, grayish yellow, coarse sand, locally, some gravel
# 7.2m, loose to medium dense, grayish yellow, fine sand
# 9.8m, very soft, gray, mud, shell fragments, coarse sand
# 22.1m, firm, grayish yellow, grayish white, pinkish red, clay, mottled, coarse sand
# 23.9m, soft, gray, mud, shell fragments, humic matter
# 27.6m, firm, gray, clay, shell fragments, medium sand
# 31.7m, stiff, grayish white, grayish yellow, clay, mottled, fine sand
# 36.9m, firm to stiff, gray, clay, mottled, humic matter
# 41.5m, medium dense, lightly gray, coarse sand, mottled, clay, medium sand
# 43.2m, grayish yellow, grayish white, residual soil, the core recovered as medium dense silty, slakes readily in water
#
# ===== query_text11 =====
# 0.0m, grayish white, grayish yellow, cobbles & boulders
# 18.4m, loose, gray, black, medium sand, mottled, some mud, shell fragments
# 18.9m, firm, grayish yellow, clay, locally, some coarse sand
# 21.9m, medium dense, grayish yellow, gray, coarse sand, some clay
# 22.9m, grayish yellow, grayish white, residual soil, the core recovered as medium dense silty, slakes readily in water
# 26.8m, very weak, grayish yellow, grayish white, brownish red, completely decomposed, coarse-grained granite
# 29.0m, weak, grayish yellow, grayish white, brownish red, highly decomposed, coarse-grained granite
# 33.35m, moderately strong, grayish yellow, pinkish red spotted, single black biotite crystals, occasional clusters of small biotite flakes, inequigranular, moderately decomposed, coarse grained granite
#
# ===== query_text12 =====
# 0.0m, loose, grayish yellow fine sand
# 4.0m, very soft, dark gray clay, occasionally, organic materials
# 10.0m, loose, gray coarse sand, shell fragments
# 17.5m, firm, gray clay locally laminated, sand
# 22.2m, soft to firm, grayish yellow clay
# 30.3m, strong to very strong, grayish yellow, pinkish red, grayish white, moderately decomposed granite
# 31.35m, stiff to very stiff, grayish yellow residual soil
# 35.0m, weak, grayish yellow, pinkish red, grayish white, completely decomposed granite
# 41.9m, strong to very strong, grayish yellow, pinkish red, grayish white, moderately decomposed granite
#
# ===== query_text13 =====
# 0.0m, loose, yellowish brown, sandy gravel/silty clay, many subangular to subrounded cobbles, occasional rounded boulders, many domestic refuse, pieces of concrete, masonry, brick
# 3.0m, loose, grayish yellow, gravelly sand, some shell fragments
# 6.2m, loose to medium dense, grayish yellow, fine sand
# 10.5m, loose to medium dense, grayish yellow, gravelly sand
# 15.5m, medium dense to dense, gray, locally, grayish yellow, coarse sand
# 21.0m, dense, gray, medium sand
# 23.0m, weak, grayish yellow, brownish red spotted, grayish white, highly decomposed, coarse-grained granite
# 23.8m, strong, grayish white spotted, single black biotite crystals, occasional clusters of small biotite flakes, inequigranular, moderately decomposed, coarse grained granite
# 25.05m, medium dense, grayish yellow, silty, slakes readily in water, residual soil
# 33.0m, extremely weak, grayish yellow, brownish red, spotted, grayish white, completely decomposed, coarse-grained granite
# 36.8m, weak, grayish yellow, brownish red spotted, grayish white, highly decomposed, coarse-grained granite
# 65.2m, strong, grayish white spotted, single black biotite crystals, occasional clusters of small biotite flakes, inequigranular, moderately decomposed, coarse grained granite
#
# ===== query_text14 =====
# 0.0m, loose, grayish yellow, coarse sand, little fine gravel
# 5.5m, soft, gray, clay, little shell fragments, fine sand
# 7.0m, loose, gray fine sand, some shell fragment, little clay
# 9.1m, soft to firm, gray, clay, little shell fragments, fine sand
# 17.3m, stiff, grayish yellow, brownish red spotted grayish white, silty sand, a little fine sand
# 19.1m, medium dense, grayish yellow, clayey sand
# 23.1m, stiff, grayish white, grayish yellow, brownish red clay
# 27.0m, stiff to very stiff, grayish yellow, brownish red spotted grayish white, clay
# 32.5m, dense, grayish yellow, clayey medium to coarse sand
#
# ===== query_text15 =====
# 0.0m, loose, grayish yellow, brownish red, very silty fine to coarse sand, occasional gravel
# 4.9m, very soft, gray, brownish gray, silty clay, occasional fine sand, shell fragments
# 8.0m, very loose to lose, gray, clayey silty coarse sand, some shell fragments
# 10.5m, medium dense, orangish brown, silty gravelly coarse sand
# 13.5m, firm, reddish brown, very sandy silty clay
# 14.5m, medium dense, grayish yellow spotted brownish red, gravelly coarse sand, occasional clay
# 16.8m, firm to stiff, gray, light gray, grayish yellow, silty clay, occasional fine to medium sand
# 19.0m, medium dense to dense, orangish brown, gravelly coarse sand
# 23.0m, extremely weak, reddish brown, grayish white, completely decomposed coarse grained granite
# 34.0m, extremely weak, reddish brown, brownish yellow, grayish white, brownish red, completely decomposed coarse-grained granite
# 40.6m, weak, brownish yellow, grayish white, highly decomposed coarse-grained granite
# 41.6m, moderately strong to strong, brownish white, grayish brown spotted pinkish red, moderately to slightly decomposed coarse grained granite
#
# ===== query_text16 =====
# 0.0m, cobbles, concrete, construction waste
# 9.5m, loose, gray to yellowish gray fine sand
# 11.5m, soft to firm, dark gray clay, organic materials, shell fragments
# 15.0m, loose, gray to yellowish gray medium sand
# 17.0m, soft, dark gray clay, occasionally, organic materials, fine sand
# 17.7m, stiff to very stiff, grayish yellow residual soil
# 20.66m, moderately strong to strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite
#
# ===== query_text17 =====
# 0.0m, loose to medium dense, grayish yellow, medium to coarse sand, occasionally, gravels, cobbles
# 4.7m, firm, gray, coarse sand, some mud
# 7.0m, very soft, gray, mud, a little fine sand
# 12.1m, very loose, gray, medium sand, some shell fragments, clay
# 14.2m, medium dense, grayish yellow, brownish red, silty
# 17.0m, strong, grayish white, pink mottled grayish green, moderately decomposed medium to coarse grained granite
# 17.45m, extremely weak, grayish yellow, grayish white mottled pink, completely decomposed granite
# 21.9m, strong, grayish white, pink mottled grayish green, moderately decomposed medium to coarse grained granite
#
# ===== query_text18 =====
# 0.0m, loose, gray to yellowish fine sand
# 7.5m, very soft, dark gray clay, occasionally, shell fragments, organic materials
# 16.5m, loose, gray coarse sand, around 15% very soft clay
# 18.7m, soft to stiff, gray clay locally laminated, sand
# 21.0m, very soft, dark gray clay, occasionally, organic materials
# 29.2m, firm to stiff, gray clay
# 35.0m, weak, grayish yellow pinkish red, grayish white, completely decomposed granite
# 40.2m, strong, grayish yellow pinkish red, grayish white, moderately decomposed granite
#
# ===== query_text19 =====
# 0.0m, loose, gray to yellowish fine sand
# 4.5m, very soft, dark gray clay, occasionally, organic materials
# 13.0m, loose, gray coarse sand
# 17.5m, firm, dark gray clay, occasionally, organic materials
# 21.0m, medium dense, gray to yellowish coarse sand
# 23.5m, soft, dark gray clay, occasionally, organic materials
# 31.0m, firm, gray to yellowish clay locally laminated, sand
# 33.5m, weak, grayish yellow pinkish red, grayish white, completely decomposed granite
# 38.7m, strong grayish yellow pinkish red, grayish white, moderately decomposed granite occasional, highly decomposed granite
# 40.2m, weak, grayish yellow pinkish red, grayish white, highly decomposed granite
# 42.62m, strong to very strong, grayish yellow pinkish red, grayish white, moderately decomposed granite
#
# ===== query_text20 =====
# 0.0m, loose, grayish yellow fine sand
# 7.8m, very soft, dark gray clay, occasionally, humus
# 9.8m, loose, gray coarse sand
# 17.3m, firm, gray clay locally laminated, sand
# 20.0m, firm, grayish yellow clay
# 22.8m, soft, dark gray clay, occasionally, humus
# 28.0m, stiff to very stiff, grayish yellow sandy clay
# 31.0m, weak, grayish yellow pinkish red, grayish white, completely decomposed granite
# 34.5m, weak, grayish yellow pinkish red, grayish white, highly decomposed granite
# 36.86m, strong to very strong, grayish yellow pinkish red, grayish white, moderately decomposed granite, highly decomposed
# 37.86m, weak, grayish yellow pinkish red, grayish white, highly decomposed granite
# 40.5m, strong to very strong, grayish yellow pinkish red, grayish white, moderately decomposed granite

# %%
blocks = [query_texts[f'query_text{i}'] for i in range(1, 21)]
blocks
# Out:
# ['0.0m, loose, gray to yellowish fine sand\n7.4m, very soft, dark gray clay, occasional humus\n18.7m, loose, gray coarse sand\n19.5m, firm, gray to yellowish clay locally laminated, sand\n25.0m, soft, dark gray clay, occasional humus\n25.7m, firm, gray to yellowish clay locally laminated, sand\n28.9m, soft to firm, gray clay\n32.4m, medium dense, gray to yellowish coarse sand\n34.0m, firm, gray clay\n36.5m, weak, grayish yellow, pinkish red, grayish white, completely decomposed granite\n37.6m, strong, grayish yellow, pinkish red, grayish white, moderately decomposed granite\n38.2m, weak, grayish yellow, pinkish red, grayish white, completely decomposed granite\n42.0m, weak, grayish yellow, pinkish red, grayish white, highly decomposed granite\n48.32m, strong to very strong, grayish yellow pinkish red, grayish white, moderately decomposed granite',
#  '0.0m, loose, gray to yellowish fine sand\n9.5m, loose, gray coarse sand, very soft clay\n13.5m, very soft, dark gray clay, occasionally, humus, fine sand, shells\n16.8m, firm to stiff, gray to yellowish clay locally laminated, sand\n20.5m, very soft, dark gray clay, occasionally, organic materials\n23.2m, strong, grayish yellow, pinkish red, grayish white, moderately decomposed granite\n24.57m, stiff to very stiff, grayish yellow residual soil\n28.72m, strong to very strong, grayish yellow, pinkish red, grayish white, moderately decomposed granite',
#  '0.0m, loose, gray to yellowish fine sand, cobbles\n9.5m, loose, grayish yellow coarse sand, shell fragments\n15.4m, soft, dark gray clay, occasionally, humus, sand\n18.0m, stiff, grayish yellow clay, locally laminated, sand\n21.0m, very soft, dark gray clay, occasionally, humus\n25.0m, stiff to very stiff, grayish yellow sandy clay\n28.5m, weak, grayish yellow, pinkish red, grayish white, completely decomposed granite\n36.37m, strong, grayish yellow, pinkish red, grayish white, highly decomposed granite\n44.7m, strong to very strong, grayish yellow, pinkish red, grayish white, moderately decomposed granite',
#  '0.0m, cobbles, concrete, construction waste\n9.5m, loose, gray to yellowish gray fine sand\n11.5m, soft to firm, dark gray clay, organic materials, shell fragments\n15.0m, loose, gray to yellowish gray medium sand\n17.0m, soft, dark gray clay, occasionally, organic materials, fine sand\n17.7m, stiff to very stiff, grayish yellow residual soil\n20.66m, moderately strong to strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite',
#  '0.0m, boulders involved, sand, granite\n7.8m, loose, gray fine sand, shell fragments, occasionally, very soft clay\n10.2m, very soft, dark gray clay, occasionally, organic materials, shell fragments\n13.5m, loose to medium dense, gray to yellowish gray coarse sand\n17.6m, firm, gray to yellowish gray clay occasionally, sand\n20.5m, medium dense, gray to yellowish gray coarse clayey sand\n21.5m, firm, gray to yellowish gray coarse sandy clay\n24.2m, firm, gray clay occasionally, fine sand, organic materials\n26.5m, loose, gray to yellowish gray coarse clayey sand\n27.6m, medium dense, gray to yellowish gray coarse sand\n31.0m, firm, gray to yellowish gray coarse sandy clay\n32.5m, stiff to very stiff, grayish yellow residual soil\n36.5m, extremely weak, grayish yellow pinkish red, grayish white, completely decomposed granite\n38.5m, extremely weak, grayish yellow pinkish red, grayish white, highly decomposed granite\n42.7m, medium strong, grayish yellow pinkish red, grayish white, moderately decomposed granite',
#  '0.0m, loose, gray to yellowish fine sand\n7.5m, very soft, dark gray clay, occasionally, shell fragments, organic materials\n16.0m, loose, gray coarse sand, around 15% very soft clay\n18.3m, soft to stiff, gray clay locally laminated, sand\n20.6m, very soft, dark gray clay, occasionally, organic materials\n29.0m, firm to stiff, gray clay\n35.0m, weak, grayish yellow pinkish red, grayish white, completely decomposed granite\n37.0m, weak, grayish yellow pinkish red, grayish white, highly decomposed granite\n40.3m, strong, grayish yellow pinkish red, grayish white, moderately decomposed granite\n42.14m, weak, grayish yellow pinkish red, grayish white, highly decomposed granite\n43.54m, strong to very strong, grayish yellow pinkish red, grayish white, moderately decomposed granite',
#  '0.0m, loose, occasionally coarse dense, brown medium backfill sand\n2.8m, very soft, dark gray clay, occasionally, organic materials, shell fragments\n15.6m, firm, gray clay, locally laminated, sand\n22.5m, loose, gray coarse sand\n26.5m, soft, gray clay locally laminated, sand\n29.8m, firm to stiff, gray clay, sand\n32.0m, stiff to very stiff, grayish yellow residual soil\n36.0m, weak, grayish yellow pinkish red, grayish white, completely decomposed granite\n42.0m, weak, grayish yellow pinkish red, grayish white, highly decomposed granite\n56.55m, strong to very strong, grayish yellow pinkish red, grayish white, moderately decomposed granite',
#  '0.0m, loose, gray to yellowish fine sand\n7.6m, very soft, dark gray clay, occasional humus\n8.5m, loose, gray coarse sand\n12.9m, weak, grayish yellow pinkish red, grayish white, completely decomposed granite\n18.0m, weak, grayish yellow pinkish red, grayish white, highly decomposed granite\n31.98m, strong to very strong, grayish yellow pinkish red, grayish white, moderately decomposed granite',
#  '0.0m, loose, gray to yellowish fine sand\n5.8m, very soft, dark gray clay, occasional humus\n8.6m, loose, gray coarse sand, very soft clay\n12.5m, very soft, dark gray clay, occasional humus\n16.5m, loose, gray coarse sand occasionally, clay\n20.5m, stiff to very stiff, grayish yellow residual soil\n25.0m, weak, grayish yellow pinkish red, grayish white, completely decomposed granite\n29.0m, weak, grayish yellow pinkish red, grayish white, highly decomposed granite\n35.05m, strong to very strong, grayish yellow pinkish red, grayish white, moderately decomposed granite',
#  '0.0m, medium dense, grayish yellow, coarse sand, locally, some gravel\n7.2m, loose to medium dense, grayish yellow, fine sand\n9.8m, very soft, gray, mud, shell fragments, coarse sand\n22.1m, firm, grayish yellow, grayish white, pinkish red, clay, mottled, coarse sand\n23.9m, soft, gray, mud, shell fragments, humic matter\n27.6m, firm, gray, clay, shell fragments, medium sand\n31.7m, stiff, grayish white, grayish yellow, clay, mottled, fine sand\n36.9m, firm to stiff, gray, clay, mottled, humic matter\n41.5m, medium dense, lightly gray, coarse sand, mottled, clay, medium sand\n43.2m, grayish yellow, grayish white, residual soil, the core recovered as medium dense silty, slakes readily in water',
#  '0.0m, grayish white, grayish yellow, cobbles & boulders\n18.4m, loose, gray, black, medium sand, mottled, some mud, shell fragments\n18.9m, firm, grayish yellow, clay, locally, some coarse sand\n21.9m, medium dense, grayish yellow, gray, coarse sand, some clay\n22.9m, grayish yellow, grayish white, residual soil, the core recovered as medium dense silty, slakes readily in water\n26.8m, very weak, grayish yellow, grayish white, brownish red, completely decomposed, coarse-grained granite\n29.0m, weak, grayish yellow, grayish white, brownish red, highly decomposed, coarse-grained granite\n33.35m, moderately strong, grayish yellow, pinkish red spotted, single black biotite crystals, occasional clusters of small biotite flakes, inequigranular, moderately decomposed, coarse grained granite',
#  '0.0m, loose, grayish yellow fine sand\n4.0m, very soft, dark gray clay, occasionally, organic materials\n10.0m, loose, gray coarse sand, shell fragments\n17.5m, firm, gray clay locally laminated, sand\n22.2m, soft to firm, grayish yellow clay\n30.3m, strong to very strong, grayish yellow, pinkish red, grayish white, moderately decomposed granite\n31.35m, stiff to very stiff, grayish yellow residual soil\n35.0m, weak, grayish yellow, pinkish red, grayish white, completely decomposed granite\n41.9m, strong to very strong, grayish yellow, pinkish red, grayish white, moderately decomposed granite',
#  '0.0m, loose, yellowish brown, sandy gravel/silty clay, many subangular to subrounded cobbles, occasional rounded boulders, many domestic refuse, pieces of concrete, masonry, brick\n3.0m, loose, grayish yellow, gravelly sand, some shell fragments\n6.2m, loose to medium dense, grayish yellow, fine sand\n10.5m, loose to medium dense, grayish yellow, gravelly sand\n15.5m, medium dense to dense, gray, locally, grayish yellow, coarse sand\n21.0m, dense, gray, medium sand\n23.0m, weak, grayish yellow, brownish red spotted, grayish white, highly decomposed, coarse-grained granite\n23.8m, strong, grayish white spotted, single black biotite crystals, occasional clusters of small biotite flakes, inequigranular, moderately decomposed, coarse grained granite\n25.05m, medium dense, grayish yellow, silty, slakes readily in water, residual soil\n33.0m, extremely weak, grayish yellow, brownish red, spotted, grayish white, completely decomposed, coarse-grained granite\n36.8m, weak, grayish yellow, brownish red spotted, grayish white, highly decomposed, coarse-grained granite\n65.2m, strong, grayish white spotted, single black biotite crystals, occasional clusters of small biotite flakes, inequigranular, moderately decomposed, coarse grained granite',
#  '0.0m, loose, grayish yellow, coarse sand, little fine gravel\n5.5m, soft, gray, clay, little shell fragments, fine sand\n7.0m, loose, gray fine sand, some shell fragment, little clay\n9.1m, soft to firm, gray, clay, little shell fragments, fine sand\n17.3m, stiff, grayish yellow, brownish red spotted grayish white, silty sand, a little fine sand\n19.1m, medium dense, grayish yellow, clayey sand\n23.1m, stiff, grayish white, grayish yellow, brownish red clay\n27.0m, stiff to very stiff, grayish yellow, brownish red spotted grayish white, clay\n32.5m, dense, grayish yellow, clayey medium to coarse sand',
#  '0.0m, loose, grayish yellow, brownish red, very silty fine to coarse sand, occasional gravel\n4.9m, very soft, gray, brownish gray, silty clay, occasional fine sand, shell fragments\n8.0m, very loose to lose, gray, clayey silty coarse sand, some shell fragments\n10.5m, medium dense, orangish brown, silty gravelly coarse sand\n13.5m, firm, reddish brown, very sandy silty clay\n14.5m, medium dense, grayish yellow spotted brownish red, gravelly coarse sand, occasional clay\n16.8m, firm to stiff, gray, light gray, grayish yellow, silty clay, occasional fine to medium sand\n19.0m, medium dense to dense, orangish brown, gravelly coarse sand\n23.0m, extremely weak, reddish brown, grayish white, completely decomposed coarse grained granite\n34.0m, extremely weak, reddish brown, brownish yellow, grayish white, brownish red, completely decomposed coarse-grained granite\n40.6m, weak, brownish yellow, grayish white, highly decomposed coarse-grained granite\n41.6m, moderately strong to strong, brownish white, grayish brown spotted pinkish red, moderately to slightly decomposed coarse grained granite',
#  '0.0m, cobbles, concrete, construction waste\n9.5m, loose, gray to yellowish gray fine sand\n11.5m, soft to firm, dark gray clay, organic materials, shell fragments\n15.0m, loose, gray to yellowish gray medium sand\n17.0m, soft, dark gray clay, occasionally, organic materials, fine sand\n17.7m, stiff to very stiff, grayish yellow residual soil\n20.66m, moderately strong to strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite',
#  '0.0m, loose to medium dense, grayish yellow, medium to coarse sand, occasionally, gravels, cobbles\n4.7m, firm, gray, coarse sand, some mud\n7.0m, very soft, gray, mud, a little fine sand\n12.1m, very loose, gray, medium sand, some shell fragments, clay\n14.2m, medium dense, grayish yellow, brownish red, silty\n17.0m, strong, grayish white, pink mottled grayish green, moderately decomposed medium to coarse grained granite\n17.45m, extremely weak, grayish yellow, grayish white mottled pink, completely decomposed granite\n21.9m, strong, grayish white, pink mottled grayish green, moderately decomposed medium to coarse grained granite',
#  '0.0m, loose, gray to yellowish fine sand\n7.5m, very soft, dark gray clay, occasionally, shell fragments, organic materials\n16.5m, loose, gray coarse sand, around 15% very soft clay\n18.7m, soft to stiff, gray clay locally laminated, sand\n21.0m, very soft, dark gray clay, occasionally, organic materials\n29.2m, firm to stiff, gray clay\n35.0m, weak, grayish yellow pinkish red, grayish white, completely decomposed granite\n40.2m, strong, grayish yellow pinkish red, grayish white, moderately decomposed granite',
#  '0.0m, loose, gray to yellowish fine sand\n4.5m, very soft, dark gray clay, occasionally, organic materials\n13.0m, loose, gray coarse sand\n17.5m, firm, dark gray clay, occasionally, organic materials\n21.0m, medium dense, gray to yellowish coarse sand\n23.5m, soft, dark gray clay, occasionally, organic materials\n31.0m, firm, gray to yellowish clay locally laminated, sand\n33.5m, weak, grayish yellow pinkish red, grayish white, completely decomposed granite\n38.7m, strong grayish yellow pinkish red, grayish white, moderately decomposed granite occasional, highly decomposed granite\n40.2m, weak, grayish yellow pinkish red, grayish white, highly decomposed granite\n42.62m, strong to very strong, grayish yellow pinkish red, grayish white, moderately decomposed granite',
#  '0.0m, loose, grayish yellow fine sand\n7.8m, very soft, dark gray clay, occasionally, humus\n9.8m, loose, gray coarse sand\n17.3m, firm, gray clay locally laminated, sand\n20.0m, firm, grayish yellow clay\n22.8m, soft, dark gray clay, occasionally, humus\n28.0m, stiff to very stiff, grayish yellow sandy clay\n31.0m, weak, grayish yellow pinkish red, grayish white, completely decomposed granite\n34.5m, weak, grayish yellow pinkish red, grayish white, highly decomposed granite\n36.86m, strong to very strong, grayish yellow pinkish red, grayish white, moderately decomposed granite, highly decomposed\n37.86m, weak, grayish yellow pinkish red, grayish white, highly decomposed granite\n40.5m, strong to very strong, grayish yellow pinkish red, grayish white, moderately decomposed granite']

# %%
import re
import pandas as pd
import numpy as np
import faiss
from transformers import AutoTokenizer, AutoModel
import torch

df = pd.read_csv(r"TRAIN.csv", header=0, index_col=0, encoding='utf-8').reset_index()

model_name = "moka-ai/m3e-base"  
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

def get_embedding(text, window_size=510, stride=255):
    tokens = tokenizer.encode(text, add_special_tokens=False)
    chunks = []
    for i in range(0, len(tokens), stride):
        chunk = tokens[i:i+window_size]
        if len(chunk) > window_size:
            chunk = chunk[:window_size]
        chunks.append([tokenizer.cls_token_id] + chunk + [tokenizer.sep_token_id])
    
    embeddings = []
    for chunk in chunks:
        inputs = {"input_ids": torch.tensor([chunk])}
        with torch.no_grad():
            outputs = model(**inputs)
        embedding = outputs.last_hidden_state.mean(dim=1).squeeze().numpy()
        embeddings.append(embedding)
    
    return np.mean(embeddings, axis=0) if embeddings else np.zeros(model.config.hidden_size)

df['DDL'] = df.apply(lambda row: f"{row['Description']}, {row['Layer']}", axis=1)
df["embedding"] = df["DDL"].apply(get_embedding)

embeddings_array = np.vstack(df["embedding"].values)
print("Shape:", embeddings_array.shape)  

dimension = embeddings_array.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings_array.astype('float32'))  

print("Done")

# %%
import pandas as pd
import numpy as np
import faiss


layers = ['FIL', 'MD', 'ALL', 'CDG', 'HDG', 'GRA']
layer_systems = {}

for layer in layers:

    layer_df = df[df['Layer'] == layer].copy().reset_index(drop=True)
    
    if layer_df.empty:
        print(f"Error：{layer} No data")
        continue

    if 'embedding' not in layer_df.columns:
        raise ValueError(f" 'embedding' in {layer} is missing")
    
    embeddings = np.stack(layer_df['embedding'].values).astype('float32')
    index = faiss.IndexFlatL2(embeddings.shape[1])
    index.add(embeddings)
    
    layer_systems[layer] = {
        'data': layer_df,
        'index': index
    }

def retrieve_layer_samples(layer_system, query_text, sample_ratio=0.05):
 
    data = layer_system['data']
    index = layer_system['index']
    
    sample_size = max(1, min(
        int(len(data) * sample_ratio),
        len(data)
    ))
    
    query_embed = get_embedding(query_text).astype('float32')

    _, indices = index.search(query_embed.reshape(1, -1), sample_size)
    valid_indices = [idx for idx in indices[0] if 0 <= idx < len(data)]
    
    return data.iloc[valid_indices]['DDL'].tolist()

RAG_T = []
for block in blocks:
    block_results = []
    
    for layer in layers:
        if layer not in layer_systems:
            continue
        
        samples = retrieve_layer_samples(
            layer_system=layer_systems[layer],
            query_text=block,
            sample_ratio=0.05
        )
        
        unique_samples = list(dict.fromkeys([f"{s}" for s in samples]))
        block_results.extend(unique_samples)
    
    RAG_T.append('\n'.join(block_results))
    print()

for i, rag_text in enumerate(RAG_T):
    print(f"\n{rag_text}")
# Out:
# 0 meter, loose, grayish yellow and gray, fine sand, FIL
# 0 meter, medium dense, brownish gray, grayish yellow and brownish red, gravelsly coarse sand, with occasional cobbles, FIL
# 3.5 meter, grayish white and grayish yellow, FIL
# 0 meter, grayish white and grayish yellow, cobbles & boulders, FIL
# 7.5 meter, grayish white and grayish yellow, FIL
# 0 meter, soft, dark gray to gray, mud, MD
# 9 meter, wet, soft, light yellow to yellow clay, MD
# 12 meter, wet, soft light gray to gray and light yellow clay, MD
# 6 meter, soft, gray to dark gray, clay, MD
# 20.3 meter, medium dense, gray, grayish white, spottled grayish yellow, coarse sand, locally with a little clay , ALL
# 38.8 meter, dense, grayish yellow, grayish white, coarse sand, ALL
# 41.5 meter, firm, grayish yellow and grayish white, clay, ALL
# 11.8 meter, medium dense, grayish white and grayish yellow, silty coarse sand, ALL
# 36.5 meter, dense, grayish white and grayish yellow, fine sand. , ALL
# 32.5 meter, medium dense, grayish yellow and brownish red, clayey sand. , ALL
# 25.5 meter, Hard, yellowish gray, clay, ALL
# 12.6 meter, medium dense, grayish yellow and grayish white, medium to coarse sand with a little fine to medium gravels , ALL
# 14.7 meter, loose to medium dense, grayish white, locally grayish yellow, gravelsly sand, ALL
# 11 meter, firm, grayish yellow, grayish white, brownish red, sandy silty clay, ALL
# 28 meter, stiff, grayish yellow, grayish white and brownish red, clay, with some coarse sand, ALL
# 38.6 meter, loose to medium dense, grayish yellow and grayish white, fine sand, ALL
# 25 meter, weak, grayish yellow, pinkish red and grayish white, completely decomposed granite, CDG
# 32.85 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 41 meter, weak, grayish yellow, pinkish red and grayish white, completely decomposed granite, CDG
# 20.32 meter, extremely weak, grayish yellow pinkish red and grayish white, completely decomposed granite, CDG
# 26.8 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 39.98 meter, weak, grayish yellow pinkish red and grayish white, highly decomposed granite occasional with moderately decomposed granite, HDG
# 34.8 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 24.9 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 17.5 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 35.8 meter, strong to very strong, grayish yellow, pinkish red and grayish white, moderately decomposed  granite with highly decomposed granite, GRA
# 20.1 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 20.7 meter, strong, grayish yellow, pinkish red and grayish white, moderately decomposed granite , GRA
#
# 0.8 meter, grayish white, brownish yellow, subangular, cobbles and boulders, with some medium to coarse sand, FIL
# 0.8 meter, grayish white and brownish yellow, cobbles and boulders, subangular, with some medium to coarse sand, FIL
# 0 meter, loose to medium dense, grayish yellow and gray, medium to coarse sand with occasional gravels and soft clay, FIL
# 0 meter, medium dense, brownish gray, grayish yellow and brownish red, gravelsly coarse sand, with occasional cobbles, FIL
# 0.15 meter, loose, grayish yellow, fine sand, with a little gravelss and cobbles , FIL
# 1.8 meter, very soft, dark gray, clay, occasionally with organic materials and shell fragments, MD
# 14 meter, loose, yellowish gray and brownish gray, very gravelsly coarse sand, with occasional shell fragments, MD
# 2.5 meter, soft, dark gray, mud mixed some with sand and shell, MD
# 0 meter, very soft, dark gray clay, occasionally with organic materials and shell fragments, MD
# 23.4 meter, firm to stiff, grayish white, grayish yellow, clay, with a little medium to coarse sand, ALL
# 20.3 meter, medium dense, gray, grayish white, spottled grayish yellow, coarse sand, locally with a little clay , ALL
# 19.3 meter, firm to stiff, gray and grayish yellow, sandy clay, with some medium to coarse sand , ALL
# 21.5 meter, medium dense , gray to yellowish gray coarse  sand occasionally laminated with clay, ALL
# 23.8 meter, stiff, yellowish gray clay with fine sand and coarse sand, ALL
# 21.3 meter, firm to stiff, grayish yellow and brownish red, sandy clay, with some medium to coarse sand. , ALL
# 12.5 meter, firm to stiff, gray to yellowish gray clay occasionally with sand, ALL
# 25 meter, firm to stiff, grayish yellow and brownish yellow, very sandy silty clay, sand is medium to coarse, ALL
# 12.7 meter, stiff, grayish white, locally with brownish red, sandy clay with some medium to coarse sand and with little fine gravels , ALL
# 28 meter, stiff, grayish yellow, grayish white and brownish red, clay, with some coarse sand, ALL
# 12.6 meter, medium dense, grayish yellow and grayish white, medium to coarse sand with a little fine to medium gravels , ALL
# 10 meter, soft, dark gray clay, occasionally with organic materials and shell fragments, ALL
# 7.6 meter, medium dense, grayish yellow and grayish white, residual soil, locally with a little cobble , CDG
# 0 meter, stiff to very stiff, grayish yellow residual soil, CDG
# 13.5 meter, stiff to very stiff, grayish yellow, residual soil, CDG
# 3 meter, stiff to very stiff, grayish yellow residual soil, CDG
# 28 meter, stiff to very stiff, grayish yellow residual soil, CDG
# 20.3 meter, weak, grayish yellow and grayish white, brownish red, highly decomposed, coarse grained granite, HDG
# 57.24 meter, moderately strong to strong, yellowish pink to yellowish gray, moderately to slightly decomposed, medium grained granite, with closely to medium-spaced, GRA
# 58.57 meter, moderately strong, yellowish gray to yellowish pink, slightly moderately decomposed, medium grained granite, with closely to medium spaced, GRA
# 46.8 meter, moderately strong to strong, pink spotted grayish green and grayish white, moderately to slightly decomposed medium to coarse grained granite , GRA
# 9.75 meter, moderately strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite occasional with highly decomposed granite, GRA
# 22.81 meter, moderately strong to strong, yellowish brown to grayish pink, moderately to slightly decomposed, medium grained granite, with medium to widely-spaced, GRA
# 17.5 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
#
# 0 meter, medium dense, brownish gray, grayish yellow and brownish red, gravelsly coarse sand, with occasional cobbles, FIL
# 0.8 meter, grayish white, brownish yellow, subangular, cobbles and boulders, with some medium to coarse sand, FIL
# 0.8 meter, grayish white and brownish yellow, cobbles and boulders, subangular, with some medium to coarse sand, FIL
# 0 meter, loose, grayish yellow, medium sand, locally with gravelss and cobbles., FIL
# 0 meter, medium dense, gray to yellowish gray coarse clayey sand, with cobbles, FIL
# 14 meter, loose, yellowish gray and brownish gray, very gravelsly coarse sand, with occasional shell fragments, MD
# 2.5 meter, soft, dark gray, mud mixed some with sand and shell, MD
# 6 meter, loose to medium dense, yellowish gray, fine sand, with some shell fragments, MD
# 5.5 meter, medium dense, dark gray, very gravelsly coarse sand mixed some with mud and shell, MD
# 20.3 meter, medium dense, gray, grayish white, spottled grayish yellow, coarse sand, locally with a little clay , ALL
# 23.4 meter, firm to stiff, grayish white, grayish yellow, clay, with a little medium to coarse sand, ALL
# 38.8 meter, dense, grayish yellow, grayish white, coarse sand, ALL
# 28 meter, stiff, grayish yellow, grayish white and brownish red, clay, with some coarse sand, ALL
# 12.6 meter, medium dense, grayish yellow and grayish white, medium to coarse sand with a little fine to medium gravels , ALL
# 19.3 meter, firm to stiff, gray and grayish yellow, sandy clay, with some medium to coarse sand , ALL
# 23.8 meter, stiff, yellowish gray clay with fine sand and coarse sand, ALL
# 21.5 meter, medium dense , gray to yellowish gray coarse  sand occasionally laminated with clay, ALL
# 11.8 meter, medium dense, grayish white and grayish yellow, silty coarse sand, ALL
# 12.7 meter, stiff, grayish white, locally with brownish red, sandy clay with some medium to coarse sand and with little fine gravels , ALL
# 27.3 meter, medium dense, grayish yellow and brownish yellow, silty coarse sand, ALL
# 14.5 meter, loose, gray to yellowish gray coarse sand with shell fragments, ALL
# 36 meter, wet, stiff light yellowish brown with a little shell fragmentss and white and transparent quartz, clay with black biotite completely decomposed granite, CDG
# 32.85 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 25 meter, weak, grayish yellow, pinkish red and grayish white, completely decomposed granite, CDG
# 26.8 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 32 meter, extremely weak, brownish yellow spottled grayish white, grayish black, completely decomposed coarse grained granite, CDG
# 20.3 meter, weak, grayish yellow and grayish white, brownish red, highly decomposed, coarse grained granite, HDG
# 58.57 meter, moderately strong, yellowish gray to yellowish pink, slightly moderately decomposed, medium grained granite, with closely to medium spaced, GRA
# 57.24 meter, moderately strong to strong, yellowish pink to yellowish gray, moderately to slightly decomposed, medium grained granite, with closely to medium-spaced, GRA
# 9.75 meter, moderately strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite occasional with highly decomposed granite, GRA
# 34.8 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 38.16 meter, moderately strong to strong, yellowish brown to grayish pink, moderately to slightly decomposed, medium grained granite, with closely to widely-spaced, GRA
# 17.5 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
#
# 0 meter, medium dense, gray to yellowish gray coarse clayey sand, with construction waste, FIL
# 0 meter, medium dense, gray to yellowish gray coarse clayey  sand, with construction waste, FIL
# 0 meter, loose, grayish yellow, medium sand, locally with gravelss and cobbles., FIL
# 0 meter, loose to medium dense, grayish yellow and gray, medium to coarse sand with occasional gravels and soft clay, FIL
# 0.8 meter, grayish white and brownish yellow, cobbles and boulders, subangular, with some medium to coarse sand, FIL
# 14 meter, loose, yellowish gray and brownish gray, very gravelsly coarse sand, with occasional shell fragments, MD
# 0 meter, very soft, dark gray clay, occasionally with organic materials and shell fragments, MD
# 1.8 meter, very soft, dark gray, clay, occasionally with organic materials and shell fragments, MD
# 2.3 meter, very soft, dark gray clay, occasionally with organic materials and shell fragments, MD
# 12.5 meter, firm to stiff, gray to yellowish gray clay occasionally with sand, ALL
# 23.4 meter, firm to stiff, grayish white, grayish yellow, clay, with a little medium to coarse sand, ALL
# 19.3 meter, firm to stiff, gray and grayish yellow, sandy clay, with some medium to coarse sand , ALL
# 18 meter, firm, gray to yellowish gray clay occasionally with fine sand and organic materials, ALL
# 21.5 meter, medium dense , gray to yellowish gray coarse  sand occasionally laminated with clay, ALL
# 23.8 meter, stiff, yellowish gray clay with fine sand and coarse sand, ALL
# 11 meter, firm to stiff , gray to yellowish gray clay occasionally with fine sand, ALL
# 20.3 meter, medium dense, gray, grayish white, spottled grayish yellow, coarse sand, locally with a little clay , ALL
# 8.5 meter, firm, gray to yellowish gray clay occasionally with sand, ALL
# 21.3 meter, firm to stiff, grayish yellow and brownish red, sandy clay, with some medium to coarse sand. , ALL
# 12.6 meter, medium dense, grayish yellow and grayish white, medium to coarse sand with a little fine to medium gravels , ALL
# 25 meter, firm to stiff, grayish yellow and brownish yellow, very sandy silty clay, sand is medium to coarse, ALL
# 0 meter, stiff to very stiff, grayish yellow residual soil, CDG
# 27.75 meter, firm to stiff, grayish yellow residual soil, CDG
# 7.6 meter, medium dense, grayish yellow and grayish white, residual soil, locally with a little cobble , CDG
# 3 meter, stiff to very stiff, grayish yellow residual soil, CDG
# 13.5 meter, stiff to very stiff, grayish yellow, residual soil, CDG
# 30 meter, very weak to weak, grayish white and grayish yellow spotted pink and brownish yellow, highly decomposed medium to coarse grained granite, HDG
# 9.75 meter, moderately strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite occasional with highly decomposed granite, GRA
# 57.24 meter, moderately strong to strong, yellowish pink to yellowish gray, moderately to slightly decomposed, medium grained granite, with closely to medium-spaced, GRA
# 58.57 meter, moderately strong, yellowish gray to yellowish pink, slightly moderately decomposed, medium grained granite, with closely to medium spaced, GRA
# 41.45 meter, moderately strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite, GRA
# 37.48 meter, moderately strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite, GRA
# 46.8 meter, moderately strong to strong, pink spotted grayish green and grayish white, moderately to slightly decomposed medium to coarse grained granite , GRA
#
# 0.8 meter, grayish white, brownish yellow, subangular, cobbles and boulders, with some medium to coarse sand, FIL
# 0.8 meter, grayish white and brownish yellow, cobbles and boulders, subangular, with some medium to coarse sand, FIL
# 0 meter, medium dense, gray to yellowish gray coarse clayey sand, with cobbles, FIL
# 0 meter, medium dense, brownish gray, grayish yellow and brownish red, gravelsly coarse sand, with occasional cobbles, FIL
# 14 meter, loose, yellowish gray and brownish gray, very gravelsly coarse sand, with occasional shell fragments, MD
# 5.5 meter, medium dense, dark gray, very gravelsly coarse sand mixed some with mud and shell, MD
# 5.5 meter, soft to firm, dark gray, mud mixed with some sand, MD
# 9 meter, wet, soft, light yellow to yellow clay, MD
# 23.4 meter, firm to stiff, grayish white, grayish yellow, clay, with a little medium to coarse sand, ALL
# 20.3 meter, medium dense, gray, grayish white, spottled grayish yellow, coarse sand, locally with a little clay , ALL
# 25 meter, firm to stiff, grayish yellow and brownish yellow, very sandy silty clay, sand is medium to coarse, ALL
# 19.3 meter, firm to stiff, gray and grayish yellow, sandy clay, with some medium to coarse sand , ALL
# 21.3 meter, firm to stiff, grayish yellow and brownish red, sandy clay, with some medium to coarse sand. , ALL
# 21.5 meter, medium dense , gray to yellowish gray coarse  sand occasionally laminated with clay, ALL
# 23.8 meter, stiff, yellowish gray clay with fine sand and coarse sand, ALL
# 12.6 meter, medium dense, grayish yellow and grayish white, medium to coarse sand with a little fine to medium gravels , ALL
# 28 meter, stiff, grayish yellow, grayish white and brownish red, clay, with some coarse sand, ALL
# 12.7 meter, stiff, grayish white, locally with brownish red, sandy clay with some medium to coarse sand and with little fine gravels , ALL
# 27.5 meter, medium dense, grayish yellow and grayish white, silty coarse sand, with occasional gravels, ALL
# 11.8 meter, medium dense, grayish white and grayish yellow, silty coarse sand, ALL
# 32.85 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 7.6 meter, medium dense, grayish yellow and grayish white, residual soil, locally with a little cobble , CDG
# 26.8 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 25 meter, weak, grayish yellow, pinkish red and grayish white, completely decomposed granite, CDG
# 32 meter, extremely weak, brownish yellow spottled grayish white, grayish black, completely decomposed coarse grained granite, CDG
# 30 meter, very weak to weak, grayish white and grayish yellow spotted pink and brownish yellow, highly decomposed medium to coarse grained granite, HDG
# 34.8 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 57.24 meter, moderately strong to strong, yellowish pink to yellowish gray, moderately to slightly decomposed, medium grained granite, with closely to medium-spaced, GRA
# 9.75 meter, moderately strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite occasional with highly decomposed granite, GRA
# 41.45 meter, moderately strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite, GRA
# 24.9 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 46.8 meter, moderately strong to strong, pink spotted grayish green and grayish white, moderately to slightly decomposed medium to coarse grained granite , GRA
#
# 0 meter, medium dense, brownish gray, grayish yellow and brownish red, gravelsly coarse sand, with occasional cobbles, FIL
# 3.5 meter, grayish white and grayish yellow, FIL
# 0 meter, loose, grayish yellow and gray, fine sand, FIL
# 0 meter, loose, grayish yellow, medium sand, locally with gravelss and cobbles., FIL
# 7.5 meter, grayish white and grayish yellow, FIL
# 0 meter, soft, dark gray to gray, mud, MD
# 14 meter, loose, yellowish gray and brownish gray, very gravelsly coarse sand, with occasional shell fragments, MD
# 12 meter, wet, soft light gray to gray and light yellow clay, MD
# 1.8 meter, very soft, dark gray, clay, occasionally with organic materials and shell fragments, MD
# 20.3 meter, medium dense, gray, grayish white, spottled grayish yellow, coarse sand, locally with a little clay , ALL
# 38.8 meter, dense, grayish yellow, grayish white, coarse sand, ALL
# 41.5 meter, firm, grayish yellow and grayish white, clay, ALL
# 28 meter, stiff, grayish yellow, grayish white and brownish red, clay, with some coarse sand, ALL
# 12.7 meter, stiff, grayish white, locally with brownish red, sandy clay with some medium to coarse sand and with little fine gravels , ALL
# 23.4 meter, firm to stiff, grayish white, grayish yellow, clay, with a little medium to coarse sand, ALL
# 32.5 meter, medium dense, grayish yellow and brownish red, clayey sand. , ALL
# 11.8 meter, medium dense, grayish white and grayish yellow, silty coarse sand, ALL
# 12.6 meter, medium dense, grayish yellow and grayish white, medium to coarse sand with a little fine to medium gravels , ALL
# 27.5 meter, medium dense, grayish yellow and grayish white, silty coarse sand, with occasional gravels, ALL
# 14.7 meter, loose to medium dense, grayish white, locally grayish yellow, gravelsly sand, ALL
# 36.5 meter, dense, grayish white and grayish yellow, fine sand. , ALL
# 25 meter, weak, grayish yellow, pinkish red and grayish white, completely decomposed granite, CDG
# 32.85 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 20.32 meter, extremely weak, grayish yellow pinkish red and grayish white, completely decomposed granite, CDG
# 45.8 meter, extremely weak, grayish yellow, grayish white and brownish red, completely decomposed granite, CDG
# 26.8 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 39.98 meter, weak, grayish yellow pinkish red and grayish white, highly decomposed granite occasional with moderately decomposed granite, HDG
# 34.8 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 24.9 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 17.5 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 35.8 meter, strong to very strong, grayish yellow, pinkish red and grayish white, moderately decomposed  granite with highly decomposed granite, GRA
# 20.1 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 20.7 meter, strong, grayish yellow, pinkish red and grayish white, moderately decomposed granite , GRA
#
# 0 meter, medium dense, brownish gray, grayish yellow and brownish red, gravelsly coarse sand, with occasional cobbles, FIL
# 0 meter, loose, grayish yellow, medium sand, locally with gravelss and cobbles., FIL
# 0 meter, loose to medium dense, grayish yellow and gray, medium to coarse sand with occasional gravels and soft clay, FIL
# 0 meter, loose to medium dense, grayish yellow, black, sand, locally with some gravels ., FIL
# 2.5 meter, medium dense, grayish yellow, fine to coarse sand with occasional gravels, FIL
# 14 meter, loose, yellowish gray and brownish gray, very gravelsly coarse sand, with occasional shell fragments, MD
# 5.5 meter, medium dense, dark gray, very gravelsly coarse sand mixed some with mud and shell, MD
# 0 meter, very soft, gray to brownish gray, clay, with occasional shell fragments., MD
# 0 meter, very soft, dark gray clay, occasionally with organic materials and shell fragments, MD
# 12.6 meter, medium dense, grayish yellow and grayish white, medium to coarse sand with a little fine to medium gravels , ALL
# 20.3 meter, medium dense, gray, grayish white, spottled grayish yellow, coarse sand, locally with a little clay , ALL
# 14.7 meter, loose to medium dense, grayish white, locally grayish yellow, gravelsly sand, ALL
# 0 meter, moist, medium dense, yellowish pinkish brown, medium coarse to fine sand with fine granite fragment. Clayey sand, ALL
# 11.8 meter, medium dense, grayish white and grayish yellow, silty coarse sand, ALL
# 5.5 meter, medium dense, dark gray, very gravelsly coarse sand mixed some with shell, ALL
# 27.5 meter, medium dense, grayish yellow and grayish white, silty coarse sand, with occasional gravels, ALL
# 17.8 meter, medium dense, grayish yellow and grayish white, silty coarse sand with occasional gravels, ALL
# 38.3 meter, dense to very dense, grayish yellow and grayish white, coarse to gravelsly sand , ALL
# 38.8 meter, dense, grayish yellow, grayish white, coarse sand, ALL
# 12.7 meter, stiff, grayish white, locally with brownish red, sandy clay with some medium to coarse sand and with little fine gravels , ALL
# 10 meter, soft, dark gray clay, occasionally with organic materials and shell fragments, ALL
# 32.85 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 45.8 meter, extremely weak, grayish yellow, grayish white and brownish red, completely decomposed granite, CDG
# 25 meter, weak, grayish yellow, pinkish red and grayish white, completely decomposed granite, CDG
# 26.8 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 39.5 meter, extremely weak, grayish yellow and grayish white mottled pink, completely decomposed granite., CDG
# 39.98 meter, weak, grayish yellow pinkish red and grayish white, highly decomposed granite occasional with moderately decomposed granite, HDG
# 4.6 meter, strong, grayish yellow, pinkish red and grayish white, moderately decomposed granite occasional with highly decomposed granite, GRA
# 9.75 meter, moderately strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite occasional with highly decomposed granite, GRA
# 35.8 meter, strong to very strong, grayish yellow, pinkish red and grayish white, moderately decomposed  granite with highly decomposed granite, GRA
# 34.8 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 17.5 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 24.9 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
#
# 0 meter, loose, grayish yellow and gray, fine sand, FIL
# 0 meter, medium dense, brownish gray, grayish yellow and brownish red, gravelsly coarse sand, with occasional cobbles, FIL
# 0 meter, loose to medium dense, grayish yellow and gray, medium to coarse sand with occasional gravels and soft clay, FIL
# 0.15 meter, loose, grayish yellow, fine sand, with a little gravelss and cobbles , FIL
# 0 meter, loose, grayish yellow, medium sand, locally with gravelss and cobbles., FIL
# 0 meter, soft, dark gray to gray, mud, MD
# 3.5 meter, very soft, dark gray clay, occasionally with humus and sand, MD
# 9 meter, wet, soft, light yellow to yellow clay, MD
# 6 meter, soft, gray to dark gray, clay, MD
# 20.3 meter, medium dense, gray, grayish white, spottled grayish yellow, coarse sand, locally with a little clay , ALL
# 12.6 meter, medium dense, grayish yellow and grayish white, medium to coarse sand with a little fine to medium gravels , ALL
# 11.8 meter, medium dense, grayish white and grayish yellow, silty coarse sand, ALL
# 0 meter, moist, medium dense, yellowish pinkish brown, medium coarse to fine sand with fine granite fragment. Clayey sand, ALL
# 38.8 meter, dense, grayish yellow, grayish white, coarse sand, ALL
# 8.5 meter, firm, gray to yellowish gray clay occasionally with sand, ALL
# 14.7 meter, loose to medium dense, grayish white, locally grayish yellow, gravelsly sand, ALL
# 21.5 meter, medium dense , gray to yellowish gray coarse  sand occasionally laminated with clay, ALL
# 12.7 meter, stiff, grayish white, locally with brownish red, sandy clay with some medium to coarse sand and with little fine gravels , ALL
# 21.9 meter, medium dense, grayish yellow and gray, coarse sand, with some clay, ALL
# 6.45 meter, loose, yellowish gray, fine to medium sand, ALL
# 23.4 meter, firm to stiff, grayish white, grayish yellow, clay, with a little medium to coarse sand, ALL
# 25 meter, weak, grayish yellow, pinkish red and grayish white, completely decomposed granite, CDG
# 32.85 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 26.8 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 17.8 meter, extremely weak, brownish white, grayish yellow spottled with pinkish red, completely decomposed, coarse grained granite, CDG
# 20.32 meter, extremely weak, grayish yellow pinkish red and grayish white, completely decomposed granite, CDG
# 20.3 meter, weak, grayish yellow and grayish white, brownish red, highly decomposed, coarse grained granite, HDG
# 17.5 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 24.9 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 34.8 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 20.1 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 20.7 meter, strong, grayish yellow, pinkish red and grayish white, moderately decomposed granite , GRA
# 35.8 meter, strong to very strong, grayish yellow, pinkish red and grayish white, moderately decomposed  granite with highly decomposed granite, GRA
#
# 0 meter, medium dense, brownish gray, grayish yellow and brownish red, gravelsly coarse sand, with occasional cobbles, FIL
# 0.8 meter, grayish white, brownish yellow, subangular, cobbles and boulders, with some medium to coarse sand, FIL
# 0.8 meter, grayish white and brownish yellow, cobbles and boulders, subangular, with some medium to coarse sand, FIL
# 0 meter, loose to medium dense, grayish yellow and gray, medium to coarse sand with occasional gravels and soft clay, FIL
# 0 meter, loose, grayish yellow and gray, fine sand, FIL
# 9 meter, wet, soft, light yellow to yellow clay, MD
# 5.5 meter, soft to firm, dark gray, mud mixed with some sand, MD
# 3.5 meter, very soft, dark gray clay, occasionally with humus and sand, MD
# 0 meter, soft, dark gray to gray, mud, MD
# 20.3 meter, medium dense, gray, grayish white, spottled grayish yellow, coarse sand, locally with a little clay , ALL
# 23.4 meter, firm to stiff, grayish white, grayish yellow, clay, with a little medium to coarse sand, ALL
# 12.7 meter, stiff, grayish white, locally with brownish red, sandy clay with some medium to coarse sand and with little fine gravels , ALL
# 23.8 meter, stiff, yellowish gray clay with fine sand and coarse sand, ALL
# 28 meter, stiff, grayish yellow, grayish white and brownish red, clay, with some coarse sand, ALL
# 12.6 meter, medium dense, grayish yellow and grayish white, medium to coarse sand with a little fine to medium gravels , ALL
# 11.8 meter, medium dense, grayish white and grayish yellow, silty coarse sand, ALL
# 8.5 meter, firm, gray to yellowish gray clay occasionally with sand, ALL
# 25 meter, firm to stiff, grayish yellow and brownish yellow, very sandy silty clay, sand is medium to coarse, ALL
# 0 meter, moist, medium dense, yellowish pinkish brown, medium coarse to fine sand with fine granite fragment. Clayey sand, ALL
# 21.3 meter, firm to stiff, grayish yellow and brownish red, sandy clay, with some medium to coarse sand. , ALL
# 38.8 meter, dense, grayish yellow, grayish white, coarse sand, ALL
# 32.85 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 25 meter, weak, grayish yellow, pinkish red and grayish white, completely decomposed granite, CDG
# 26.8 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 7.6 meter, medium dense, grayish yellow and grayish white, residual soil, locally with a little cobble , CDG
# 17.8 meter, extremely weak, brownish white, grayish yellow spottled with pinkish red, completely decomposed, coarse grained granite, CDG
# 30 meter, very weak to weak, grayish white and grayish yellow spotted pink and brownish yellow, highly decomposed medium to coarse grained granite, HDG
# 57.24 meter, moderately strong to strong, yellowish pink to yellowish gray, moderately to slightly decomposed, medium grained granite, with closely to medium-spaced, GRA
# 58.57 meter, moderately strong, yellowish gray to yellowish pink, slightly moderately decomposed, medium grained granite, with closely to medium spaced, GRA
# 34.8 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 9.75 meter, moderately strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite occasional with highly decomposed granite, GRA
# 24.9 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 17.5 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
#
# 0 meter, loose to medium dense, grayish yellow and gray, medium to coarse sand with occasional gravels and soft clay, FIL
# 0 meter, loose to medium dense, grayish yellow to dark gray, silty fine sand, FIL
# 0 meter, medium dense, grayish yellow, coarse sand, locally with some gravels, FIL
# 0 meter, medium dense, brownish gray, grayish yellow and brownish red, gravelsly coarse sand, with occasional cobbles, FIL
# 6 meter, loose to medium dense, gray, grayish white, coarse sand, locally with a little gravelss and cobbles, FIL
# 6 meter, loose to medium dense, yellowish gray, fine sand, with some shell fragments, MD
# 5.5 meter, medium dense, dark gray, very gravelsly coarse sand mixed some with mud and shell, MD
# 6 meter, wet, medium dense, light yellow to yellow clay fine sand with shell fragmentss., MD
# 14 meter, soft, dark gray, silty clay with fine to medium sand, MD
# 11.8 meter, medium dense, grayish white and grayish yellow, silty coarse sand, ALL
# 17.8 meter, medium dense, grayish yellow and grayish white, silty coarse sand with occasional gravels, ALL
# 20.3 meter, medium dense, gray, grayish white, spottled grayish yellow, coarse sand, locally with a little clay , ALL
# 27.5 meter, medium dense, grayish yellow and grayish white, silty coarse sand, with occasional gravels, ALL
# 12.6 meter, medium dense, grayish yellow and grayish white, medium to coarse sand with a little fine to medium gravels , ALL
# 27.3 meter, medium dense, grayish yellow and brownish yellow, silty coarse sand, ALL
# 15 meter, loose to medium dense, grayish yellow and gray, silty medium sand, locally coarse sand, ALL
# 21.8 meter, medium dense, grayish yellow, silty coarse sand with fine gravels , ALL
# 23.5 meter, medium dense, grayish white and brownish yellow, silty clayey coarse sand with occasional gravels, ALL
# 21.9 meter, medium dense, grayish yellow and gray, coarse sand, with some clay, ALL
# 25.5 meter, medium dense, grayish yellow, silty coarse sand with fine gravels , ALL
# 37.5 meter, medium dense, grayish white, slightly gravelsly silty coarse sand., ALL
# 31.5 meter, grayish yellow and grayish white, residual soil, the core recovered as medium dense silty ,slakes readily in water, CDG
# 22.9 meter, grayish yellow and grayish white, residual soil, the core recovered as medium dense silty, slakes readily in water, CDG
# 35.2 meter, grayish yellow and grayish white, residual soil, the core recovered as medium dense silty, slakes readily in water, CDG
# 7.6 meter, medium dense, grayish yellow and grayish white, residual soil, locally with a little cobble , CDG
# 29.2 meter, medium dense, grayish yellow , grayish white and brown, silty. , CDG
# 66.6 meter, very weak to weak, grayish yellow mottled grayish white and grayish green, highly decomposed medium to coarse grained granite, HDG
# 46.8 meter, moderately strong to strong, pink spotted grayish green and grayish white, moderately to slightly decomposed medium to coarse grained granite , GRA
# 49.7 meter, strong, pink and grayish white mottled grayish green, moderately decomposed medium to coarse grained granite, GRA
# 48.8 meter, moderately strong to strong, pink spotted grayish green and grayish white, moderately to slightly decomposed medium to coarse grained granite, GRA
# 47.6 meter, moderately strong to strong, pink spotted grayish green and grayish white, moderately to slightly decomposed medium to coarse grained granite, GRA
# 41.9 meter, strong, pink spotted grayish green and grayish white, slightly decomposed medium to coarse grained granite, GRA
# 57.24 meter, moderately strong to strong, yellowish pink to yellowish gray, moderately to slightly decomposed, medium grained granite, with closely to medium-spaced, GRA
#
# 0.8 meter, grayish white, brownish yellow, subangular, cobbles and boulders, with some medium to coarse sand, FIL
# 0.8 meter, grayish white and brownish yellow, cobbles and boulders, subangular, with some medium to coarse sand, FIL
# 0 meter, medium dense, brownish gray, grayish yellow and brownish red, gravelsly coarse sand, with occasional cobbles, FIL
# 0 meter, grayish white and grayish yellow, cobbles & boulders, FIL
# 0 meter, loose, grayish yellow, medium sand, locally with gravelss and cobbles., FIL
# 14 meter, loose, yellowish gray and brownish gray, very gravelsly coarse sand, with occasional shell fragments, MD
# 5.5 meter, medium dense, dark gray, very gravelsly coarse sand mixed some with mud and shell, MD
# 1.8 meter, very soft, dark gray, clay, occasionally with organic materials and shell fragments, MD
# 0 meter, very soft, dark gray clay, occasionally with organic materials and shell fragments, MD
# 20.3 meter, medium dense, gray, grayish white, spottled grayish yellow, coarse sand, locally with a little clay , ALL
# 11.8 meter, medium dense, grayish white and grayish yellow, silty coarse sand, ALL
# 12.6 meter, medium dense, grayish yellow and grayish white, medium to coarse sand with a little fine to medium gravels , ALL
# 9 meter, medium dense, yellowish brown, silty medium to coarse sand with some crystal and gravels, ALL
# 17.8 meter, medium dense, grayish yellow and grayish white, silty coarse sand with occasional gravels, ALL
# 27.3 meter, medium dense, grayish yellow and brownish yellow, silty coarse sand, ALL
# 27.5 meter, medium dense, grayish yellow and grayish white, silty coarse sand, with occasional gravels, ALL
# 20.5 meter, dense, yellowish brown mottled with orange, silty medium to coarse sand with some crystal and gravels, ALL
# 24 meter, medium dense, light yellowish gray, silty medium to coarse sand with crystal, ALL
# 0 meter, moist, medium dense, yellowish pinkish brown, medium coarse to fine sand with fine granite fragment. Clayey sand, ALL
# 38.8 meter, dense, grayish yellow, grayish white, coarse sand, ALL
# 16 meter, stiff, orangish brown mottled grayish yellow and light grayish white, silty clay, ALL
# 17.8 meter, extremely weak, brownish white, grayish yellow spottled with pinkish red, completely decomposed, coarse grained granite, CDG
# 32 meter, extremely weak, brownish yellow spottled grayish white, grayish black, completely decomposed coarse grained granite, CDG
# 32.85 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 55.9 meter, extremely weak, yellowish brown spottled grayish white, completely decomposed coarse grained granite, CDG
# 26.8 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 22.9 meter, weak to strong, grayish white spotted with single black biotite crystals and occasional clusters of small biotite flakes, highly to moderately decomposed, coarse grained granite, HDG
# 35.25 meter, moderately strong, grayish yellow and pinkish red spotted with single black biotite crystals and occasional clusters of small biotite flakes, inequigranular, moderately decomposed, coarse grained granite, GRA
# 25.8 meter, strong, grayish white spotted with single black biotite crystals and occasional clusters of small biotite flakes, inequigranular, moderately decomposed, coarse grained granite, GRA
# 19.5 meter, strong, grayish white spotted with single black biotite crystals and occasional clusters of small biotite flakes, inequigranular, moderately decomposed, coarse grained granite, GRA
# 21.2 meter, moderately strong, grayish white and pinkish red spotted with single black biotite crystals and occasional clusters of small biotite flakes, inequigranular, moderately decomposed, coarse grained granite, GRA
# 42.3 meter, moderately strong to strong, grayish yellow and pinkish red spotted with single black biotite crystals and occasional clusters of small biotite flakes, inequigranular, moderately decomposed, coarse grained granite., GRA
# 16.2 meter, moderately strong, grayish white and pinkish red spotted with single black biotite crystals and occasional clusters of small biotite flakes, inequigranular, moderately decomposed, coarse grained granite, GRA
#
# 0 meter, loose to medium dense, grayish yellow and gray, medium to coarse sand with occasional gravels and soft clay, FIL
# 0 meter, loose, grayish yellow, medium sand, locally with gravelss and cobbles., FIL
# 0.15 meter, loose, grayish yellow, fine sand, with a little gravelss and cobbles , FIL
# 0 meter, medium dense, brownish gray, grayish yellow and brownish red, gravelsly coarse sand, with occasional cobbles, FIL
# 0 meter, loose, grayish yellow and gray, fine sand, FIL
# 14 meter, loose, yellowish gray and brownish gray, very gravelsly coarse sand, with occasional shell fragments, MD
# 0 meter, very soft, dark gray clay, occasionally with organic materials and shell fragments, MD
# 1.8 meter, very soft, dark gray, clay, occasionally with organic materials and shell fragments, MD
# 6 meter, loose to medium dense, yellowish gray, fine sand, with some shell fragments, MD
# 20.3 meter, medium dense, gray, grayish white, spottled grayish yellow, coarse sand, locally with a little clay , ALL
# 23.4 meter, firm to stiff, grayish white, grayish yellow, clay, with a little medium to coarse sand, ALL
# 12.6 meter, medium dense, grayish yellow and grayish white, medium to coarse sand with a little fine to medium gravels , ALL
# 19.3 meter, firm to stiff, gray and grayish yellow, sandy clay, with some medium to coarse sand , ALL
# 21.3 meter, firm to stiff, grayish yellow and brownish red, sandy clay, with some medium to coarse sand. , ALL
# 10 meter, soft, dark gray clay, occasionally with organic materials and shell fragments, ALL
# 11.8 meter, loose, gray, medium sand with some shell fragmentss and a little clay , ALL
# 25 meter, firm to stiff, grayish yellow and brownish yellow, very sandy silty clay, sand is medium to coarse, ALL
# 11.8 meter, medium dense, grayish white and grayish yellow, silty coarse sand, ALL
# 21.5 meter, medium dense , gray to yellowish gray coarse  sand occasionally laminated with clay, ALL
# 12.7 meter, stiff, grayish white, locally with brownish red, sandy clay with some medium to coarse sand and with little fine gravels , ALL
# 23.2 meter, soft to firm, grayish yellow, clay, with some medium to coarse sand., ALL
# 7.6 meter, medium dense, grayish yellow and grayish white, residual soil, locally with a little cobble , CDG
# 32.85 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 25 meter, weak, grayish yellow, pinkish red and grayish white, completely decomposed granite, CDG
# 26.8 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 0 meter, stiff to very stiff, grayish yellow residual soil, CDG
# 20.3 meter, weak, grayish yellow and grayish white, brownish red, highly decomposed, coarse grained granite, HDG
# 34.8 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 17.5 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 24.9 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 46.8 meter, moderately strong to strong, pink spotted grayish green and grayish white, moderately to slightly decomposed medium to coarse grained granite , GRA
# 9.75 meter, moderately strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite occasional with highly decomposed granite, GRA
# 57.24 meter, moderately strong to strong, yellowish pink to yellowish gray, moderately to slightly decomposed, medium grained granite, with closely to medium-spaced, GRA
#
# 0.8 meter, grayish white, brownish yellow, subangular, cobbles and boulders, with some medium to coarse sand, FIL
# 0.8 meter, grayish white and brownish yellow, cobbles and boulders, subangular, with some medium to coarse sand, FIL
# 0 meter, medium dense, brownish gray, grayish yellow and brownish red, gravelsly coarse sand, with occasional cobbles, FIL
# 0 meter, grayish white and grayish yellow, cobbles & boulders, FIL
# 7.5 meter, medium dense, dark brown, medium to coarse sand with some crystal and gravels, FIL
# 14 meter, loose, yellowish gray and brownish gray, very gravelsly coarse sand, with occasional shell fragments, MD
# 5.5 meter, medium dense, dark gray, very gravelsly coarse sand mixed some with mud and shell, MD
# 18.4 meter, loose, gray, black, medium sand, mottled with some mud and shell fragments, MD
# 1.8 meter, very soft, dark gray, clay, occasionally with organic materials and shell fragments, MD
# 20.3 meter, medium dense, gray, grayish white, spottled grayish yellow, coarse sand, locally with a little clay , ALL
# 20.5 meter, dense, yellowish brown mottled with orange, silty medium to coarse sand with some crystal and gravels, ALL
# 9 meter, medium dense, yellowish brown, silty medium to coarse sand with some crystal and gravels, ALL
# 24 meter, medium dense, light yellowish gray, silty medium to coarse sand with crystal, ALL
# 11.8 meter, medium dense, grayish white and grayish yellow, silty coarse sand, ALL
# 27.3 meter, medium dense, grayish yellow and brownish yellow, silty coarse sand, ALL
# 12.6 meter, medium dense, grayish yellow and grayish white, medium to coarse sand with a little fine to medium gravels , ALL
# 17.8 meter, medium dense, grayish yellow and grayish white, silty coarse sand with occasional gravels, ALL
# 20 meter, medium dense to dense, orangish brown to light gray, medium to coarse sand with some crystal and gravels, ALL
# 27.5 meter, medium dense, grayish yellow and grayish white, silty coarse sand, with occasional gravels, ALL
# 16 meter, dense, orangish brown to light gray, silty medium to coarse sand with gravels and crystal, ALL
# 0 meter, moist, medium dense, yellowish pinkish brown, medium coarse to fine sand with fine granite fragment. Clayey sand, ALL
# 16 meter, medium dense to dense, orangish brown spottled with dark gray and yellow, silty medium to fine sand with some crystal and gravels, CDG
# 36 meter, wet, stiff light yellowish brown with a little shell fragmentss and white and transparent quartz, clay with black biotite completely decomposed granite, CDG
# 32 meter, extremely weak, brownish yellow spottled grayish white, grayish black, completely decomposed coarse grained granite, CDG
# 55.9 meter, extremely weak, yellowish brown spottled grayish white, completely decomposed coarse grained granite, CDG
# 54.27 meter, very dense, yellowish brown spottled with black and white, silty medium to coarse sand with some crystal, CDG
# 22.9 meter, weak to strong, grayish white spotted with single black biotite crystals and occasional clusters of small biotite flakes, highly to moderately decomposed, coarse grained granite, HDG
# 25.8 meter, strong, grayish white spotted with single black biotite crystals and occasional clusters of small biotite flakes, inequigranular, moderately decomposed, coarse grained granite, GRA
# 35.25 meter, moderately strong, grayish yellow and pinkish red spotted with single black biotite crystals and occasional clusters of small biotite flakes, inequigranular, moderately decomposed, coarse grained granite, GRA
# 19.5 meter, strong, grayish white spotted with single black biotite crystals and occasional clusters of small biotite flakes, inequigranular, moderately decomposed, coarse grained granite, GRA
# 42.3 meter, moderately strong to strong, grayish yellow and pinkish red spotted with single black biotite crystals and occasional clusters of small biotite flakes, inequigranular, moderately decomposed, coarse grained granite., GRA
# 21.2 meter, moderately strong, grayish white and pinkish red spotted with single black biotite crystals and occasional clusters of small biotite flakes, inequigranular, moderately decomposed, coarse grained granite, GRA
# 19.9 meter, moderately strong, grayish white and celadon spotted with single black biotite crystals and occasional clusters of small biotite flakes, inequigranular, moderately decomposed, coarse grained granite, GRA
#
# 0 meter, medium dense, brownish gray, grayish yellow and brownish red, gravelsly coarse sand, with occasional cobbles, FIL
# 0 meter, loose to medium dense, grayish yellow and gray, medium to coarse sand with occasional gravels and soft clay, FIL
# 0.8 meter, grayish white, brownish yellow, subangular, cobbles and boulders, with some medium to coarse sand, FIL
# 0.8 meter, grayish white and brownish yellow, cobbles and boulders, subangular, with some medium to coarse sand, FIL
# 0 meter, medium dense, gray to yellowish gray coarse clayey sand, with cobbles, FIL
# 14 meter, loose, yellowish gray and brownish gray, very gravelsly coarse sand, with occasional shell fragments, MD
# 6 meter, loose to medium dense, yellowish gray, fine sand, with some shell fragments, MD
# 8.8 meter, soft to firm, gray, mud, with a little fine sand and shell fragments., MD
# 5.5 meter, medium dense, dark gray, very gravelsly coarse sand mixed some with mud and shell, MD
# ...
# 2.3 meter, very soft, dark gray clay, occasionally with organic materials and shell fragments, MD
# 12.5 meter, firm to stiff, gray to yellowish gray clay occasionally with sand, ALL
# 23.4 meter, firm to stiff, grayish white, grayish yellow, clay, with a little medium to coarse sand, ALL
# 19.3 meter, firm to stiff, gray and grayish yellow, sandy clay, with some medium to coarse sand , ALL
# 18 meter, firm, gray to yellowish gray clay occasionally with fine sand and organic materials, ALL
# 21.5 meter, medium dense , gray to yellowish gray coarse  sand occasionally laminated with clay, ALL
# 23.8 meter, stiff, yellowish gray clay with fine sand and coarse sand, ALL
# 11 meter, firm to stiff , gray to yellowish gray clay occasionally with fine sand, ALL
# 20.3 meter, medium dense, gray, grayish white, spottled grayish yellow, coarse sand, locally with a little clay , ALL
# 8.5 meter, firm, gray to yellowish gray clay occasionally with sand, ALL
# 21.3 meter, firm to stiff, grayish yellow and brownish red, sandy clay, with some medium to coarse sand. , ALL
# 12.6 meter, medium dense, grayish yellow and grayish white, medium to coarse sand with a little fine to medium gravels , ALL
# 25 meter, firm to stiff, grayish yellow and brownish yellow, very sandy silty clay, sand is medium to coarse, ALL
# 0 meter, stiff to very stiff, grayish yellow residual soil, CDG
# 27.75 meter, firm to stiff, grayish yellow residual soil, CDG
# 7.6 meter, medium dense, grayish yellow and grayish white, residual soil, locally with a little cobble , CDG
# 3 meter, stiff to very stiff, grayish yellow residual soil, CDG
# 13.5 meter, stiff to very stiff, grayish yellow, residual soil, CDG
# 30 meter, very weak to weak, grayish white and grayish yellow spotted pink and brownish yellow, highly decomposed medium to coarse grained granite, HDG
# 9.75 meter, moderately strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite occasional with highly decomposed granite, GRA
# 57.24 meter, moderately strong to strong, yellowish pink to yellowish gray, moderately to slightly decomposed, medium grained granite, with closely to medium-spaced, GRA
# 58.57 meter, moderately strong, yellowish gray to yellowish pink, slightly moderately decomposed, medium grained granite, with closely to medium spaced, GRA
# 41.45 meter, moderately strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite, GRA
# 37.48 meter, moderately strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite, GRA
# 46.8 meter, moderately strong to strong, pink spotted grayish green and grayish white, moderately to slightly decomposed medium to coarse grained granite , GRA
#
# 0 meter, medium dense, brownish gray, grayish yellow and brownish red, gravelsly coarse sand, with occasional cobbles, FIL
# 0 meter, loose to medium dense, grayish yellow and gray, medium to coarse sand with occasional gravels and soft clay, FIL
# 0 meter, medium dense, grayish yellow, coarse sand, locally with some gravels, FIL
# 0 meter, loose to medium dense, grayish yellow, black, sand, locally with some gravels ., FIL
# 2.5 meter, medium dense, grayish yellow, fine to coarse sand with occasional gravels, FIL
# 0 meter, soft, dark gray to gray, mud, MD
# 0 meter, very soft, gray to brownish gray, clay, with occasional shell fragments., MD
# 8.5 meter, very soft, gray, mud, with shell fragments and coarse sand, MD
# 0 meter, very soft, brownish gray, clay, with occasional shell fragments., MD
# 12.6 meter, medium dense, grayish yellow and grayish white, medium to coarse sand with a little fine to medium gravels , ALL
# 11.8 meter, medium dense, grayish white and grayish yellow, silty coarse sand, ALL
# 20.3 meter, medium dense, gray, grayish white, spottled grayish yellow, coarse sand, locally with a little clay , ALL
# 0 meter, moist, medium dense, yellowish pinkish brown, medium coarse to fine sand with fine granite fragment. Clayey sand, ALL
# 27.5 meter, medium dense, grayish yellow and grayish white, silty coarse sand, with occasional gravels, ALL
# 17.8 meter, medium dense, grayish yellow and grayish white, silty coarse sand with occasional gravels, ALL
# 27.3 meter, medium dense, grayish yellow and brownish yellow, silty coarse sand, ALL
# 20.1 meter, medium dense, grayish yellow, coarse sand., ALL
# 38.8 meter, dense, grayish yellow, grayish white, coarse sand, ALL
# 14.7 meter, loose to medium dense, grayish white, locally grayish yellow, gravelsly sand, ALL
# 11.8 meter, loose, gray, medium sand with some shell fragmentss and a little clay , ALL
# 21.9 meter, medium dense, grayish yellow and gray, coarse sand, with some clay, ALL
# 26.8 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 32.85 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 17.8 meter, extremely weak, brownish white, grayish yellow spottled with pinkish red, completely decomposed, coarse grained granite, CDG
# 29.5 meter, extremely weak, reddish brown, brownish yellow and grayish white, completely decomposed coarse grained granite, CDG
# 25 meter, weak, grayish yellow, pinkish red and grayish white, completely decomposed granite, CDG
# 20.3 meter, weak, grayish yellow and grayish white, brownish red, highly decomposed, coarse grained granite, HDG
# 9.75 meter, moderately strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite occasional with highly decomposed granite, GRA
# 2.69 meter, moderately strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite, GRA
# 20.79 meter, moderately strong to strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite, GRA
# 21.63 meter, moderately strong to strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite, GRA
# 16.5 meter, moderately strong to strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite, GRA
# 46.8 meter, moderately strong to strong, pink spotted grayish green and grayish white, moderately to slightly decomposed medium to coarse grained granite , GRA
#
# 0 meter, loose to medium dense, grayish yellow and gray, medium to coarse sand with occasional gravels and soft clay, FIL
# 0 meter, loose, grayish yellow, medium sand, locally with gravelss and cobbles., FIL
# 0 meter, medium dense, brownish gray, grayish yellow and brownish red, gravelsly coarse sand, with occasional cobbles, FIL
# 0 meter, medium dense, gray to yellowish gray coarse clayey sand, with cobbles, FIL
# 0 meter, very soft, dark gray clay, occasionally with organic materials and shell fragments, MD
# 1.8 meter, very soft, dark gray, clay, occasionally with organic materials and shell fragments, MD
# 14 meter, loose, yellowish gray and brownish gray, very gravelsly coarse sand, with occasional shell fragments, MD
# 7.6 meter, very soft, dark gray clay, occasionally with organic materials and shell fragments, MD
# 23.4 meter, firm to stiff, grayish white, grayish yellow, clay, with a little medium to coarse sand, ALL
# 20.3 meter, medium dense, gray, grayish white, spottled grayish yellow, coarse sand, locally with a little clay , ALL
# 21.5 meter, medium dense , gray to yellowish gray coarse  sand occasionally laminated with clay, ALL
# 19.3 meter, firm to stiff, gray and grayish yellow, sandy clay, with some medium to coarse sand , ALL
# 21.3 meter, firm to stiff, grayish yellow and brownish red, sandy clay, with some medium to coarse sand. , ALL
# 12.5 meter, firm to stiff, gray to yellowish gray clay occasionally with sand, ALL
# 10 meter, soft, dark gray clay, occasionally with organic materials and shell fragments, ALL
# 8.5 meter, firm, gray to yellowish gray clay occasionally with sand, ALL
# 0 meter, moist, medium dense, yellowish pinkish brown, medium coarse to fine sand with fine granite fragment. Clayey sand, ALL
# 23.8 meter, stiff, yellowish gray clay with fine sand and coarse sand, ALL
# 25 meter, firm to stiff, grayish yellow and brownish yellow, very sandy silty clay, sand is medium to coarse, ALL
# 12.7 meter, stiff, grayish white, locally with brownish red, sandy clay with some medium to coarse sand and with little fine gravels , ALL
# 25 meter, weak, grayish yellow, pinkish red and grayish white, completely decomposed granite, CDG
# 32.85 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 36 meter, wet, stiff light yellowish brown with a little shell fragmentss and white and transparent quartz, clay with black biotite completely decomposed granite, CDG
# 26.8 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 20.32 meter, extremely weak, grayish yellow pinkish red and grayish white, completely decomposed granite, CDG
# 30 meter, very weak to weak, grayish white and grayish yellow spotted pink and brownish yellow, highly decomposed medium to coarse grained granite, HDG
# 57.24 meter, moderately strong to strong, yellowish pink to yellowish gray, moderately to slightly decomposed, medium grained granite, with closely to medium-spaced, GRA
# 34.8 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 17.5 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 46.8 meter, moderately strong to strong, pink spotted grayish green and grayish white, moderately to slightly decomposed medium to coarse grained granite , GRA
# 9.75 meter, moderately strong, grayish yellow, yellowish pink, moderately decomposed medium to coarse grained granite occasional with highly decomposed granite, GRA
# 58.57 meter, moderately strong, yellowish gray to yellowish pink, slightly moderately decomposed, medium grained granite, with closely to medium spaced, GRA
#
# 3.5 meter, grayish white and grayish yellow, FIL
# 0 meter, medium dense, brownish gray, grayish yellow and brownish red, gravelsly coarse sand, with occasional cobbles, FIL
# 0 meter, loose, grayish yellow and gray, fine sand, FIL
# 7.5 meter, grayish white and grayish yellow, FIL
# 0 meter, loose, grayish yellow, medium sand, locally with gravelss and cobbles., FIL
# 0 meter, soft, dark gray to gray, mud, MD
# 12 meter, wet, soft light gray to gray and light yellow clay, MD
# 2.9 meter, very soft, dark gray clay, occasionally with organic materials, MD
# 0 meter, wet, very soft light gray to clay gray, MD
# 20.3 meter, medium dense, gray, grayish white, spottled grayish yellow, coarse sand, locally with a little clay , ALL
# 38.8 meter, dense, grayish yellow, grayish white, coarse sand, ALL
# 41.5 meter, firm, grayish yellow and grayish white, clay, ALL
# 11.8 meter, medium dense, grayish white and grayish yellow, silty coarse sand, ALL
# 14.7 meter, loose to medium dense, grayish white, locally grayish yellow, gravelsly sand, ALL
# 36.5 meter, dense, grayish white and grayish yellow, fine sand. , ALL
# 12.6 meter, medium dense, grayish yellow and grayish white, medium to coarse sand with a little fine to medium gravels , ALL
# 27.5 meter, medium dense, grayish yellow and grayish white, silty coarse sand, with occasional gravels, ALL
# 38.6 meter, loose to medium dense, grayish yellow and grayish white, fine sand, ALL
# 32.5 meter, medium dense, grayish yellow and brownish red, clayey sand. , ALL
# 38.3 meter, dense to very dense, grayish yellow and grayish white, coarse to gravelsly sand , ALL
# 17.8 meter, medium dense, grayish yellow and grayish white, silty coarse sand with occasional gravels, ALL
# 25 meter, weak, grayish yellow, pinkish red and grayish white, completely decomposed granite, CDG
# 32.85 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 20.32 meter, extremely weak, grayish yellow pinkish red and grayish white, completely decomposed granite, CDG
# 41 meter, weak, grayish yellow, pinkish red and grayish white, completely decomposed granite, CDG
# 26.8 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 39.98 meter, weak, grayish yellow pinkish red and grayish white, highly decomposed granite occasional with moderately decomposed granite, HDG
# 34.8 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 24.9 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 35.8 meter, strong to very strong, grayish yellow, pinkish red and grayish white, moderately decomposed  granite with highly decomposed granite, GRA
# 17.5 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 20.1 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 20.7 meter, strong, grayish yellow, pinkish red and grayish white, moderately decomposed granite , GRA
#
# 0 meter, loose, grayish yellow and gray, fine sand, FIL
# 3.5 meter, grayish white and grayish yellow, FIL
# 0 meter, medium dense, brownish gray, grayish yellow and brownish red, gravelsly coarse sand, with occasional cobbles, FIL
# 0 meter, grayish white and grayish yellow, cobbles & boulders, FIL
# 7.5 meter, grayish white and grayish yellow, FIL
# 9 meter, wet, soft, light yellow to yellow clay, MD
# 0 meter, soft, dark gray to gray, mud, MD
# 12 meter, wet, soft light gray to gray and light yellow clay, MD
# 6 meter, soft, gray to dark gray, clay, MD
# 20.3 meter, medium dense, gray, grayish white, spottled grayish yellow, coarse sand, locally with a little clay , ALL
# 38.8 meter, dense, grayish yellow, grayish white, coarse sand, ALL
# 41.5 meter, firm, grayish yellow and grayish white, clay, ALL
# 28 meter, stiff, grayish yellow, grayish white and brownish red, clay, with some coarse sand, ALL
# 12.7 meter, stiff, grayish white, locally with brownish red, sandy clay with some medium to coarse sand and with little fine gravels , ALL
# 23.4 meter, firm to stiff, grayish white, grayish yellow, clay, with a little medium to coarse sand, ALL
# 41.8 meter, stiff, grayish yellow and brownish red, sandy silty clay, ALL
# 11 meter, firm, grayish yellow, grayish white, brownish red, sandy silty clay, ALL
# 36.5 meter, dense, grayish white and grayish yellow, fine sand. , ALL
# 11.8 meter, medium dense, grayish white and grayish yellow, silty coarse sand, ALL
# 32.5 meter, medium dense, grayish yellow and brownish red, clayey sand. , ALL
# 22.6 meter, very stiff, pinkish red, grayish yellow, clay, ALL
# 25 meter, weak, grayish yellow, pinkish red and grayish white, completely decomposed granite, CDG
# 32.85 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 41 meter, weak, grayish yellow, pinkish red and grayish white, completely decomposed granite, CDG
# 20.32 meter, extremely weak, grayish yellow pinkish red and grayish white, completely decomposed granite, CDG
# 26.8 meter, very weak, grayish yellow and grayish white, brownish red, completely decomposed, coarse grained granite, CDG
# 39.98 meter, weak, grayish yellow pinkish red and grayish white, highly decomposed granite occasional with moderately decomposed granite, HDG
# 34.8 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 35.8 meter, strong to very strong, grayish yellow, pinkish red and grayish white, moderately decomposed  granite with highly decomposed granite, GRA
# 24.9 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 17.5 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
# 20.7 meter, strong, grayish yellow, pinkish red and grayish white, moderately decomposed granite , GRA
# 20.1 meter, medium strong, grayish yellow pinkish red and grayish white, moderately decomposed granite, GRA
